# %%
import nump
import pandas numpy as  np
# Out:
#   Cell In[6], line 1
#     import pandas numpy as  np
#                   ^
# SyntaxError: invalid syntax

# %%
s=pd.Series([1,4,np.nan,None],index=[1,5,3,5])
print(s)
# Out:
# 1    1.0
# 5    4.0
# 3    NaN
# 5    NaN
# dtype: float64
