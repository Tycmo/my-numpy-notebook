# %%
import pandas as pd

# %%
s=pd.Series([12,14,15,16])
print(s)
# Out:
# 0    12
# 1    14
# 2    15
# 3    16
# dtype: int64

# %%
s=pd.Series([15,14,16,18],index=["A","B","C","D"])
print(s)
# Out:
# A    15
# B    14
# C    16
# D    18
# dtype: int64

# %%
s=pd.Series([15,14,16,18],index=["A","B","C","D"],name="月份")
print(s)
# Out:
# A    15
# B    14
# C    16
# D    18
# Name: 月份, dtype: int64

# %% [markdown]
# # 用字典来创建

# %%
print(pd.Series({"A":155,"hj":687855,"8585":47858585}))
# Out:
# A            155
# hj        687855
# 8585    47858585
# dtype: int64

# %%
print(pd.Series(s,index=["A"]))
# Out:
# A    15
# Name: 月份, dtype: int64
