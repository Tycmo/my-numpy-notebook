# %% [raw]
# 根据你的进度，NumPy基础已经学完，接下来需要**通过大量练习巩固核心知识点**，为后续的Pandas、数据分析和机器学习打下扎实基础。下面我按知识点分类，列出你**必须掌握的9大类技能**，每类提供10个典型练习题。你可以每天抽1小时完成2-3类，一周内全部练完。
#
# ---
#
# ## **NumPy核心知识分类及练习题**
#
# ### **一、数组创建与基本属性（10题）**
# 1. 创建一个长度为10的一维全零数组。
# 2. 创建一个3×4的全1矩阵，数据类型为int32。
# 3. 使用`arange`生成从5到50、步长为5的数组。
# 4. 使用`linspace`生成0到π之间20个点的数组。
# 5. 创建一个3×3的单位矩阵。
# 6. 创建一个对角线上元素为[1,2,3,4]的4×4矩阵。
# 7. 创建一个随机整数数组，形状为(4,5)，范围在0-100之间。
# 8. 创建一个3×3×2的三维随机数组（均匀分布）。
# 9. 分别查看数组的维度(`ndim`)、形状(`shape`)、元素个数(`size`)和数据类型(`dtype`)。
# 10. 将数组的数据类型从float64转换为int32。
#
# ### **二、索引与切片（10题）**
# 1. 创建一个5×5的随机矩阵，提取第2行（索引从0开始）。
# 2. 提取上述矩阵的第1列和第3列。
# 3. 提取矩阵的2-4行、1-3列（左闭右开）。
# 4. 提取矩阵中所有偶数行、奇数列。
# 5. 将矩阵的中心3×3子矩阵全部赋值为0。
# 6. 使用花式索引提取指定行[0,2,4]。
# 7. 使用花式索引提取指定列[1,3]并组成新矩阵。
# 8. 创建一个一维数组，提取所有大于10的元素。
# 9. 将数组中所有负数替换为0。
# 10. 获取数组中最大值和最小值的索引（使用`argmax`和`argmin`）。
#
# ### **三、数组操作（形状变换、合并、分割）（10题）**
# 1. 将一维数组(12,)重塑为3×4矩阵。
# 2. 将3×4矩阵展平为一维数组。
# 3. 创建两个2×3矩阵，垂直堆叠成4×3。
# 4. 创建两个3×2矩阵，水平堆叠成3×4。
# 5. 将3×4矩阵按行分割成3个1×4的数组。
# 6. 将3×4矩阵按列分割成2个3×2的数组。
# 7. 使用`newaxis`将一维数组(5,)变成列向量(5,1)。
# 8. 使用`concatenate`沿指定轴合并两个三维数组。
# 9. 给数组增加一个维度（例如从(3,4)变成(1,3,4)）。
# 10. 删除数组中大小为1的维度（`squeeze`）。
#
# ### **四、数学运算与通用函数（ufunc）（10题）**
# 1. 对数组每个元素求平方根。
# 2. 对数组每个元素求自然对数。
# 3. 计算两个数组的对应元素之和、差、积、商。
# 4. 计算数组的三角函数（sin, cos）并比较。
# 5. 使用`exp`计算e的幂。
# 6. 对数组四舍五入到小数点后2位。
# 7. 使用`modf`将数组拆分成整数和小数部分。
# 8. 实现数组的逐元素比较（大于、小于、等于），返回布尔数组。
# 9. 使用`where`实现条件赋值：将数组中大于0.5的元素替换为1，否则为0。
# 10. 计算数组的绝对值、符号函数（`sign`）。
#
# ### **五、线性代数（10题）**
# 1. 计算两个2×2矩阵的乘积（`dot`或`@`）。
# 2. 计算3×3矩阵的行列式。
# 3. 求3×3矩阵的逆矩阵。
# 4. 解线性方程组：
#    \[
#    \begin{cases}
#    2x + y = 5 \\
#    x - 3y = 6
#    \end{cases}
#    \]
#    用矩阵形式`Ax = b`求解。
# 5. 计算矩阵的特征值和特征向量。
# 6. 计算两个向量的内积和外积。
# 7. 对矩阵进行奇异值分解（SVD）。
# 8. 计算矩阵的迹（对角线元素之和）。
# 9. 求矩阵的范数（Frobenius范数）。
# 10. 使用`lstsq`求解超定线性方程组（最小二乘）。
#
# ### **六、统计与随机数（10题）**
# 1. 计算数组的均值、中位数、标准差。
# 2. 计算数组的方差、最小值、最大值。
# 3. 对矩阵按列求和、按行求均值。
# 4. 计算数组的累积和（`cumsum`）和累积积（`cumprod`）。
# 5. 生成1000个服从标准正态分布的随机数，并计算均值和方差。
# 6. 生成1000个服从均匀分布U(0,1)的随机数，绘制直方图（用matplotlib）。
# 7. 从给定数组`[1,2,3,4,5]`中随机抽取10个样本（可重复）。
# 8. 打乱一个数组的顺序（`shuffle`或`permutation`）。
# 9. 设置随机种子，使结果可复现。
# 10. 生成一个5×5的随机整数矩阵，并找到每行的最大值及其位置。
#
# ### **七、广播机制（5题，补充到10题可结合前几类）**
# 1. 创建一个3×1的数组和一个1×3的数组，相加后观察广播结果。
# 2. 对一个3×4矩阵，加上一个长度为4的一维向量，解释广播规则。
# 3. 对一个3×4矩阵，加上一个长度为3的一维向量，能否广播？如何调整？
# 4. 使用广播将矩阵的每一行减去该行的均值（中心化）。
# 5. 使用广播将矩阵的每一列除以该列的标准差（标准化）。
# 6. 计算两个形状分别为(3,1)和(1,4)的数组的外积（用广播）。
# 7. 创建一个3×4矩阵，将其每一元素乘以一个标量（自然广播）。
# 8. 创建一个3×4矩阵和一个3×1数组，相除。
# 9. 创建一个4×3矩阵和一个3×2矩阵，利用广播实现某种操作（需设计）。
# 10. 用广播生成一个3维网格坐标（例如`np.arange(5)[:, None, None] + ...`）。
#
# ### **八、文件输入输出（5题，可结合前几类）**
# 1. 将一维数组保存为二进制`.npy`文件，再读取回来。
# 2. 将多个数组保存为压缩的`.npz`文件，并读取。
# 3. 将二维数组保存为文本文件（如CSV），再用`loadtxt`读取。
# 4. 使用`genfromtxt`读取带缺失值的文本文件。
# 5. 将数组保存为TXT格式，并指定分隔符为逗号。
#
# ### **九、高级索引与布尔索引（10题）**
# 1. 使用布尔数组提取数组中所有大于0的元素。
# 2. 将数组中所有非数字（NaN）替换为0。
# 3. 统计数组中大于某个阈值的元素个数。
# 4. 使用布尔索引修改满足条件的元素（如将所有奇数变为-1）。
# 5. 找出数组中同时满足两个条件的元素（例如大于5且小于10）。
# 6. 用花式索引提取指定位置的元素（索引数组）。
# 7. 创建一个3×3矩阵，用两个一维索引数组（行索引和列索引）提取对应元素。
# 8. 使用`take`和`put`函数进行索引和赋值。
# 9. 使用`ix_`函数构造索引器，提取不连续的行和列。
# 10. 对一维数组，找出局部最大值的索引（即比前后元素都大的位置）。
#
# ---
#
# ## **练习建议**
# - **每天2-3类，每类选做5-10题**，不用一次做完所有，关键是理解背后原理。
# - **先独立思考**，遇到不会的查文档（NumPy官方文档或百度），不要直接搜答案。
# - **将代码保存到GitHub仓库**，命名如`numpy_practice`，方便以后回顾。
# - **结合Matplotlib可视化**部分结果（如直方图、散点图），为后续数据分析热身。
#
# 完成这些练习后，你对NumPy的掌握将达到**熟练应用**的程度，接下来就可以无缝衔接Pandas和机器学习基础了。如果有哪类题目觉得困难，随时来问我！
